# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.sample(1)
# Out:
#         budget                                             genres  \
# 1132  42000000  [{"id": 14, "name": "Fantasy"}, {"id": 53, "na...
#
#                                 homepage     id  \
# 1132  http://www.redridinghoodmovie.com/  49730
#
#                                                keywords original_language  \
# 1132  [{"id": 1442, "name": "winter"}, {"id": 2486, ...                en
#
#        original_title                                           overview  \
# 1132  Red Riding Hood  Valerie is in love with a brooding outsider, P...
#
#       popularity                               production_companies  \
# 1132   45.151657  [{"name": "Appian Way", "id": 562}, {"name": "...
#
#                                    production_countries release_date  \
# 1132  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   2011-03-11
#
#        revenue  runtime                          spoken_languages    status  \
# 1132  89162162    100.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#             tagline            title  vote_average  vote_count
# 1132  Who's afraid?  Red Riding Hood           5.6         922

# %%
credits.sample(1)
# Out:
#       movie_id                     title  \
# 2264     43935  Dylan Dog: Dead of Night
#
#                                                    cast  \
# 2264  [{"cast_id": 6, "character": "Dylan Dog", "cre...
#
#                                                    crew
# 2264  [{"credit_id": "52fe466cc3a36847f80fe299", "de...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
movies['keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
# genres id keywords overview title

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
# cast crew

# %%
movies=movies.merge(credits , on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 864.2+ KB

# %%
movies.sample(3)
# Out:
#         budget                                             genres  \
# 1248  40000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 2017  22700000  [{"id": 35, "name": "Comedy"}, {"id": 878, "na...
# 750   60000000                     [{"id": 28, "name": "Action"}]
#
#                                             homepage     id  \
# 1248                                             NaN  13536
# 2017  http://www.mgm.com/view/movie/1873/Spaceballs/    957
# 750                 http://www.stateofplaymovie.net/  16995
#
#                                                keywords original_language  \
# 1248  [{"id": 9826, "name": "murder"}, {"id": 180668...                en
# 2017  [{"id": 803, "name": "android"}, {"id": 1280, ...                en
# 750   [{"id": 417, "name": "corruption"}, {"id": 441...                en
#
#        original_title                                           overview  \
# 1248  City By The Sea  A man struggling to come to terms with the sin...
# 2017       Spaceballs  When the nefarious Dark Helmet hatches a plan ...
# 750     State of Play  Handsome, unflappable U.S. Congressman Stephen...
#
#       popularity                               production_companies  ...  \
# 1248    3.476966  [{"name": "Warner Bros. Pictures", "id": 174},...  ...
# 2017   39.890798  [{"name": "Brooksfilms Ltd.", "id": 617}, {"na...  ...
# 750    21.685719  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
#
#      runtime                                   spoken_languages    status  \
# 1248   108.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2017    96.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 750    127.0  [{"iso_639_1": "cn", "name": "\u5e7f\u5dde\u8b...  Released
#
#                                                 tagline            title  \
# 1248  When you're searching for a killer... the last...  City By The Sea
# 2017                       May the schwartz be with you       Spaceballs
# 750                                      Find The Truth    State of Play
#
#      vote_average vote_count movie_id  \
# 1248          5.7         92    13536
# 2017          6.7        902      957
# 750           6.7        484    16995
#
#                                                    cast  \
# 1248  [{"cast_id": 1, "character": "Vincent LaMarca"...
# 2017  [{"cast_id": 24, "character": "President Skroo...
# 750   [{"cast_id": 2, "character": "Cal McAffrey", "...
#
#                                                    crew
# 1248  [{"credit_id": "52fe45779251416c7505784f", "de...
# 2017  [{"credit_id": "52fe4293c3a36847f8029829", "de...
# 750   [{"credit_id": "52fe46fc9251416c7508a343", "de...
#
# [3 rows x 23 columns]

# %%
# genres id keywords overview title 
# cast crew
movies = movies[['genres' , 'id' ,'keywords' , 'overview' , 'title' , 'cast' , 'crew']]

# %%
movies.shape
# Out:
# (4809, 7)

# %%
movies.sample(4)
# Out:
#                                                  genres      id  \
# 2609  [{"id": 35, "name": "Comedy"}, {"id": 80, "nam...     115
# 1999  [{"id": 10749, "name": "Romance"}, {"id": 878,...  152601
# 1671  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...    2008
# 2877  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   10362
#
#                                                keywords  \
# 2609  [{"id": 418, "name": "white russian"}, {"id": ...
# 1999  [{"id": 310, "name": "artificial intelligence"...
# 1671  [{"id": 964, "name": "servant"}, {"id": 2280, ...
# 2877  [{"id": 2038, "name": "love of one's life"}, {...
#
#                                                overview             title  \
# 2609  Jeffrey "The Dude" Lebowski, a Los Angeles sla...  The Big Lebowski
# 1999  In the not so distant future, Theodore, a lone...               Her
# 1671  An orphaned girl, driven by poverty at such a ...       The Promise
# 2877  A depressed man moves back in with his parents...        Two Lovers
#
#                                                    cast  \
# 2609  [{"cast_id": 12, "character": "The Dude", "cre...
# 1999  [{"cast_id": 5, "character": "Theodore", "cred...
# 1671  [{"cast_id": 13, "character": "Princess Qingch...
# 2877  [{"cast_id": 3, "character": "Leonard", "credi...
#
#                                                    crew
# 2609  [{"credit_id": "52fe4219c3a36847f8004109", "de...
# 1999  [{"credit_id": "52fe4b269251416c910d16a5", "de...
# 1671  [{"credit_id": "52fe432bc3a36847f803fb19", "de...
# 2877  [{"credit_id": "58a5b005c3a3681f100008ae", "de...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4809 non-null   object
#  1   id        4809 non-null   int64
#  2   keywords  4809 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
movies['genres'].apply(ast.literal_eval)[0][0]
# Out:
# {'id': 28, 'name': 'Action'}

# %%
list=[]
for i in movies['genres'].apply(ast.literal_eval)[0]:
    list.append(i['name'])
print(list)
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies['genres'].apply(ast.literal_eval)
# Out:
# 0       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1       [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3       [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#                               ...
# 4804    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4805    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 4806    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4807                                                   []
# 4808                  [{'id': 99, 'name': 'Documentary'}]
# Name: genres, Length: 4809, dtype: object

# %%
def process(object):
    list=[]
    for i in object:
        list.append(i['name'])
    return list

# %%
movies['genres']=movies['genres'].apply(ast.literal_eval).apply(process)

# %%
movies.sample(3)
# Out:
#                                     genres      id  \
# 2508            [Action, Adventure, Drama]   38717
# 3166     [Horror, Comedy, Science Fiction]   68684
# 242   [Action, Adventure, Science Fiction]  166424
#
#                                                keywords  \
# 2508  [{"id": 6075, "name": "sport"}, {"id": 10183, ...
# 3166  [{"id": 6270, "name": "high school"}, {"id": 9...
# 242   [{"id": 3822, "name": "teleportation"}, {"id":...
#
#                                                overview           title  \
# 2508  In 1971, air-conditioner repairman and boat en...         Madison
# 3166  As a killer named Cinderhella stalks the stude...       Detention
# 242   Four young outsiders teleport to a dangerous u...  Fantastic Four
#
#                                                    cast  \
# 2508  [{"cast_id": 3, "character": "Jim McCormick", ...
# 3166  [{"cast_id": 16, "character": "Riley Jones", "...
# 242   [{"cast_id": 169, "character": "Reed Richards ...
#
#                                                    crew
# 2508  [{"credit_id": "52fe46d69251416c91061523", "de...
# 3166  [{"credit_id": "52fe479dc3a368484e0d0d1b", "de...
# 242   [{"credit_id": "566e93a9925141664f00eb4c", "de...

# %%
movies['keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies['keywords']=movies['keywords'].apply(ast.literal_eval).apply(process)

# %%
movies.sample(3)
# Out:
#                                                 genres      id  \
# 72   [Action, Adventure, Crime, Fantasy, Science Fi...  297761
# 415                          [Action, Science Fiction]   49049
# 228      [Action, Science Fiction, Adventure, Mystery]   75612
#
#                                               keywords  \
# 72   [dc comics, shared universe, anti hero, secret...
# 415  [usa, corruption, crime fighter, judge, metrop...
# 228  [spacecraft, dystopia, space, drone, imax, hum...
#
#                                               overview          title  \
# 72   From DC Comics comes the Suicide Squad, an ant...  Suicide Squad
# 415  In the future, America is a dystopian wastelan...          Dredd
# 228  Jack Harper is one of the last few drone repai...       Oblivion
#
#                                                   cast  \
# 72   [{"cast_id": 9, "character": "Floyd Lawton / D...
# 415  [{"cast_id": 2, "character": "Judge Dredd", "c...
# 228  [{"cast_id": 1, "character": "Jack Harper", "c...
#
#                                                   crew
# 72   [{"credit_id": "58415a5a9251417d590062b1", "de...
# 415  [{"credit_id": "52fe4783c3a36847f8139ea9", "de...
# 228  [{"credit_id": "52fe4909c3a368484e11767f", "de...

# %%
movies['cast'][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender": 2, "id": 59231, "name": "Joel David Moore", "order": 6}, {"cast_id": 9, "character": "Moat", "credit_id": "52fe48009251416c750ac9e5", "gender": 1, "id": 30485, "name": "CCH Pounder", "order": 7}, {"cast_id": 11, "character": "Eytukan", "credit_id": "52fe48009251416c750ac9ed", "gender": 2, "id": 15853, "name": "Wes Studi", "order": 8}, {"cast_id": 10, "character": "Tsu\'Tey", "credit_id": "52fe48009251416c750ac9e9", "gender": 2, "id": 10964, "name": "Laz Alonso", "order": 9}, {"cast_id": 12, "character": "Dr. Max Patel", "credit_id": "52fe48009251416c750ac9f1", "gender": 2, "id": 95697, "name": "Dileep Rao", "order": 10}, {"cast_id": 13, "character": "Lyle Wainfleet", "credit_id": "52fe48009251416c750ac9f5", "gender": 2, "id": 98215, "name": "Matt Gerald", "order": 11}, {"cast_id": 32, "character": "Private Fike", "credit_id": "52fe48009251416c750aca5b", "gender": 2, "id": 154153, "name": "Sean Anthony Moran", "order": 12}, {"cast_id": 33, "character": "Cryo Vault Med Tech", "credit_id": "52fe48009251416c750aca5f", "gender": 2, "id": 397312, "name": "Jason Whyte", "order": 13}, {"cast_id": 34, "character": "Venture Star Crew Chief", "credit_id": "52fe48009251416c750aca63", "gender": 2, "id": 42317, "name": "Scott Lawrence", "order": 14}, {"cast_id": 35, "character": "Lock Up Trooper", "credit_id": "52fe48009251416c750aca67", "gender": 2, "id": 986734, "name": "Kelly Kilgour", "order": 15}, {"cast_id": 36, "character": "Shuttle Pilot", "credit_id": "52fe48009251416c750aca6b", "gender": 0, "id": 1207227, "name": "James Patrick Pitt", "order": 16}, {"cast_id": 37, "character": "Shuttle Co-Pilot", "credit_id": "52fe48009251416c750aca6f", "gender": 0, "id": 1180936, "name": "Sean Patrick Murphy", "order": 17}, {"cast_id": 38, "character": "Shuttle Crew Chief", "credit_id": "52fe48009251416c750aca73", "gender": 2, "id": 1019578, "name": "Peter Dillon", "order": 18}, {"cast_id": 39, "character": "Tractor Operator / Troupe", "credit_id": "52fe48009251416c750aca77", "gender": 0, "id": 91443, "name": "Kevin Dorman", "order": 19}, {"cast_id": 40, "character": "Dragon Gunship Pilot", "credit_id": "52fe48009251416c750aca7b", "gender": 2, "id": 173391, "name": "Kelson Henderson", "order": 20}, {"cast_id": 41, "character": "Dragon Gunship Gunner", "credit_id": "52fe48009251416c750aca7f", "gender": 0, "id": 1207236, "name": "David Van Horn", "order": 21}, {"cast_id": 42, "character": "Dragon Gunship Navigator", "credit_id": "52fe48009251416c750aca83", "gender": 0, "id": 215913, "name": "Jacob Tomuri", "order": 22}, {"cast_id": 43, "character": "Suit #1", "credit_id": "52fe48009251416c750aca87", "gender": 0, "id": 143206, "name": "Michael Blain-Rozgay", "order": 23}, {"cast_id": 44, "character": "Suit #2", "credit_id": "52fe48009251416c750aca8b", "gender": 2, "id": 169676, "name": "Jon Curry", "order": 24}, {"cast_id": 46, "character": "Ambient Room Tech", "credit_id": "52fe48009251416c750aca8f", "gender": 0, "id": 1048610, "name": "Luke Hawker", "order": 25}, {"c ...

# %%
def process2(object):
    list=[]
    counter=0
    for i in object:
        counter=counter+1
        if counter>3:
            break
        list.append(i['name'])
        
    return list

# %%
movies['cast']=movies['cast'].apply(ast.literal_eval).apply(process2)

# %%
movies.sample(3)
# Out:
#                                         genres    id  \
# 3352                 [Thriller, Action, Crime]  8068
# 3395               [Mystery, Drama, Adventure]  1956
# 3043  [Action, Comedy, Crime, Drama, Thriller]  9515
#
#                                                keywords  \
# 3352  [gunslinger, anti terror, ambush, mexico, show...
# 3395  [desperation, highway, wilderness, getting los...
# 3043  [mexico city, midlife crisis, cocktail, indepe...
#
#                                                overview        title  \
# 3352  A gunslinger is embroiled in a war with a loca...    Desperado
# 3395  Two friends named Gerry become lost in the des...        Gerry
# 3043  The life of Danny Wright, a salesman forever o...  The Matador
#
#                                                    cast  \
# 3352  [Antonio Banderas, Salma Hayek, Joaquim de Alm...
# 3395                        [Casey Affleck, Matt Damon]
# 3043         [Pierce Brosnan, Greg Kinnear, Hope Davis]
#
#                                                    crew
# 3352  [{"credit_id": "52fe4490c3a36847f809d4ed", "de...
# 3395  [{"credit_id": "52fe4326c3a36847f803e023", "de...
# 3043  [{"credit_id": "52fe4502c3a36847f80b7217", "de...

# %%
movies['crew'][2]
# Out:
# '[{"credit_id": "54805967c3a36829b5002c41", "department": "Sound", "gender": 2, "id": 153, "job": "Original Music Composer", "name": "Thomas Newman"}, {"credit_id": "52fe4d22c3a368484e1d8d77", "department": "Directing", "gender": 2, "id": 39, "job": "Director", "name": "Sam Mendes"}, {"credit_id": "5677cd99925141691a005333", "department": "Art", "gender": 1, "id": 8384, "job": "Set Decoration", "name": "Anna Pinnock"}, {"credit_id": "52fe4d22c3a368484e1d8d8d", "department": "Writing", "gender": 2, "id": 932, "job": "Screenplay", "name": "John Logan"}, {"credit_id": "562fc9bb92514129fe0006b4", "department": "Writing", "gender": 2, "id": 932, "job": "Story", "name": "John Logan"}, {"credit_id": "5654d41c92514145c3000373", "department": "Art", "gender": 2, "id": 4248, "job": "Production Design", "name": "Dennis Gassner"}, {"credit_id": "52fe4d22c3a368484e1d8d71", "department": "Writing", "gender": 2, "id": 9856, "job": "Characters", "name": "Ian Fleming"}, {"credit_id": "54805989c3a36829ae0022d8", "department": "Editing", "gender": 0, "id": 3904, "job": "Editor", "name": "Lee Smith"}, {"credit_id": "5677df82c3a3681683008748", "department": "Sound", "gender": 2, "id": 7538, "job": "Music Editor", "name": "Bill Bernstein"}, {"credit_id": "5720e370c3a368117e00045b", "department": "Production", "gender": 2, "id": 8784, "job": "Co-Producer", "name": "Daniel Craig"}, {"credit_id": "5522fdd09251416d4a0024b6", "department": "Costume & Make-Up", "gender": 1, "id": 11227, "job": "Costume Design", "name": "Jany Temime"}, {"credit_id": "5677cc9ac3a368167c0089b5", "department": "Production", "gender": 1, "id": 10496, "job": "Casting", "name": "Debbie McWilliams"}, {"credit_id": "52fe4d22c3a368484e1d8d7d", "department": "Production", "gender": 1, "id": 10666, "job": "Producer", "name": "Barbara Broccoli"}, {"credit_id": "5720e3afc3a368117e00046a", "department": "Production", "gender": 0, "id": 11268, "job": "Line Producer", "name": "Roberto Malerba"}, {"credit_id": "5677df58c3a368167c008c82", "department": "Sound", "gender": 0, "id": 40827, "job": "Music Editor", "name": "Peter Clarke"}, {"credit_id": "5677dd1ec3a36816890085d3", "department": "Sound", "gender": 0, "id": 14764, "job": "Sound Designer", "name": "Christopher Assells"}, {"credit_id": "566046b9c3a36875f400323a", "department": "Sound", "gender": 0, "id": 14765, "job": "Supervising Sound Editor", "name": "Per Hallberg"}, {"credit_id": "5677ccab925141691a00530f", "department": "Production", "gender": 0, "id": 36108, "job": "Casting", "name": "Nicole Schmied"}, {"credit_id": "5677cfe4c3a36816850087d2", "department": "Production", "gender": 0, "id": 36108, "job": "Casting Associate", "name": "Nicole Schmied"}, {"credit_id": "562fc984c3a3681b5400e16f", "department": "Writing", "gender": 2, "id": 10783, "job": "Screenplay", "name": "Robert Wade"}, {"credit_id": "562fc9cec3a3681b4b00d168", "department": "Writing", "gender": 2, "id": 10783, "job": "Story", "name": "Robert Wade"}, {"credit_id": "562fc976c3a3681b5c00dd64", "department": "Writing", "gender": 0, "id": 10782, "job": "Screenplay", "name": "Neal Purvis"}, {"credit_id": "562fc9d79251414ad800c103", "department": "Writing", "gender": 0, "id": 10782, "job": "Story", "name": "Neal Purvis"}, {"credit_id": "5720e61d9251414235000477", "department": "Production", "gender": 2, "id": 10876, "job": "Executive Producer", "name": "Callum McDougall"}, {"credit_id": "562fc9a89251414ad800c0fe", "department": "Writing", "gender": 2, "id": 21339, "job": "Screenplay", "name": "Jez Butterworth"}, {"credit_id": "570bd7f2c3a36802a9000412", "department": "Art", "gender": 0, "id": 23425, "job": "Supervising Art Director", "name": "Chris Lowe"}, {"credit_id": "5677e45ac3a368168b0084fd", "department": "Art", "gender": 0, "id": 23491, "job": "Assistant Art Director", "name": "Roxana Alexandru "}, {"credit_id": "5677e29c925141691a00561c", "department": "Crew", "gender": 0, "id": 23774, "job": "Makeup Effects", "name": "Jo Grover"}, {"credit_id": "5677cf849251 ...

# %%
def process3(object):
    list=[]
    for i in object:
        if i['job']=='Director':
            list.append(i['name'])
            break
    return list

# %%
movies['crew']=movies['crew'].apply(ast.literal_eval).apply(process3)

# %%
movies.sample(3)
# Out:
#                         genres     id  \
# 4534            [Crime, Drama]  12281
# 493           [Drama, Romance]    453
# 2128  [Comedy, Drama, Romance]  33644
#
#                                                keywords  \
# 4534  [suicide, alcohol, secret, birthday, lake, ore...
# 493   [individual, schizophrenia, massachusetts, lov...
# 2128  [black people, age difference, jamaica, vacati...
#
#                                                overview  \
# 4534  Teenagers living in small-town Oregon take a b...
# 493   At Princeton University, John Nash struggles t...
# 2128  Through good times and bad, Stella and Delilah...
#
#                                title  \
# 4534                      Mean Creek
# 493                 A Beautiful Mind
# 2128  How Stella Got Her Groove Back
#
#                                                 cast                     crew
# 4534  [Rory Culkin, Scott Mechlowicz, Trevor Morgan]      [Jacob Aaron Estes]
# 493    [Russell Crowe, Ed Harris, Jennifer Connelly]             [Ron Howard]
# 2128   [Angela Bassett, Taye Diggs, Whoopi Goldberg]  [Kevin Rodney Sullivan]

# %%
def clean_cast(object):
    cleaned = [name.replace(" ", "") for name in object]
    return cleaned

# %%
movies['cast']=movies['cast'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#         genres      id                                           keywords  \
# 2845   [Drama]  205220  [mother, washington d.c., journalist, adoption...
# 4692   [Drama]   48035  [faith, independent film, religion, religious ...
# 4218  [Horror]  298584  [vacation, remake, woods, burned alive, murder...
#
#                                                overview        title  \
# 2845  A woman searches for her adult son, who was ta...    Philomena
# 4692  How do we understand faith and prayer, and wha...        Ordet
# 4218  In this grisly remake of the 2002 horror hit, ...  Cabin Fever
#
#                                                    cast                   crew
# 2845       [JudiDench, SteveCoogan, SophieKennedyClark]       [Stephen Frears]
# 4692  [BirgitteFederspiel, PrebenLerdorffRye, Henrik...  [Carl Theodor Dreyer]
# 4218       [MatthewDaddario, SamuelDavis, DustinIngram]       [Travis Zariwny]

# %%
movies['crew']=movies['crew'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#                                           genres      id  \
# 12                  [Adventure, Fantasy, Action]      58
# 4624                                     [Drama]   91721
# 4740  [Thriller, Action, Drama, Science Fiction]  270554
#
#                                                keywords  \
# 12    [witch, fortune teller, bondage, exotic island...
# 4624                                                 []
# 4740                                                 []
#
#                                                overview  \
# 12    Captain Jack Sparrow works his way out of a bl...
# 4624  A proud black man and his school-teacher wife ...
# 4740  When their home security system malfunctions, ...
#
#                                            title  \
# 12    Pirates of the Caribbean: Dead Man's Chest
# 4624                           Nothing But a Man
# 4740                                    Echo Dr.
#
#                                              cast               crew
# 12     [JohnnyDepp, OrlandoBloom, KeiraKnightley]    [GoreVerbinski]
# 4624      [IvanDixon, AbbeyLincoln, JuliusHarris]    [MichaelRoemer]
# 4740  [JohnathanHurley, JordanSavage, DaneBowman]  [PatrickRyanSims]

# %%
movies['genres']=movies['genres'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#                                    genres     id  \
# 2440  [Fantasy, Drama, Thriller, Romance]   1491
# 718    [Action, ScienceFiction, Thriller]   8914
# 2184                  [Animation, Family]  13682
#
#                                                keywords  \
# 2440  [magic, princess, love, rivalry, vienna austri...
# 718   [shark attack, shark, alzheimer's disease, kil...
# 2184                                                 []
#
#                                                overview  \
# 2440  With his eye on a lovely aristocrat, a gifted ...
# 718   On a remote former submarine refueling facilit...
# 2184  Who or what exactly is a Heffalump? The lovabl...
#
#                        title                                       cast  \
# 2440         The Illusionist  [EdwardNorton, JessicaBiel, PaulGiamatti]
# 718            Deep Blue Sea      [ThomasJane, SaffronBurrows, LLCoolJ]
# 2184  Pooh's Heffalump Movie  [JimCummings, JohnFiedler, NikitaHopkins]
#
#                crew
# 2440   [NeilBurger]
# 718   [RennyHarlin]
# 2184  [FrankNissen]

# %%
def lower(object):
    return [name.lower() for name in object]

# %%
movies['genres']=movies['genres'].apply(lower)
movies['cast']=movies['cast'].apply(lower)
movies['keywords']=movies['keywords'].apply(lower)
movies['crew']=movies['crew'].apply(lower)
movies.sample(5)
# Out:
#                            genres      id  \
# 1859          [animation, family]   20694
# 1181            [comedy, romance]    9889
# 1875     [thriller, crime, drama]  190955
# 3512           [action, thriller]   58626
# 3583  [animation, family, comedy]   16508
#
#                                                keywords  \
# 1859                                  [kids and family]
# 1181  [overweight, beauty, hypnosis, overweight man,...
# 1875                                                 []
# 3512                                                 []
# 3583  [journalism, dance, daydream, friendship, poll...
#
#                                                overview             title  \
# 1859  Rugrats Go Wild is a 2003 crossover animated f...   Rugrats Go Wild
# 1181  A shallow man falls in love with a 300 pound w...       Shallow Hal
# 1875  Two brothers, on either side of the law, face ...        Blood Ties
# 3512  A disgruntled man creates a hit list with a st...      The Hit List
# 3583  Doug and his pal Skeeter set's out to find the...  Doug's 1st Movie
#
#                                                 cast              crew
# 1859        [e.g.daily, nancycartwright, kathsoucie]   [nortonvirgien]
# 1181     [gwynethpaltrow, jackblack, jasonalexander]   [bobbyfarrelly]
# 1875       [cliveowen, billycrudup, marioncotillard]  [guillaumecanet]
# 3512  [cubagoodingjr., colehauser, jonathanlapaglia]  [williamkaufman]
# 3583       [thomasmchugh, frednewman, chrisphillips]    [mauricejoyce]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4809 non-null   object
#  1   id        4809 non-null   int64
#  2   keywords  4809 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
def process5(object):
    return object.split()

# %%
movies.dropna(inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.4+ KB

# %%
movies['overview']=movies['overview'].apply(process5)

# %%
print(process5("Hey how are you 1950"))
# Out:
# ['Hey', 'how', 'are', 'you', '1950']

# %%
movies['overview']=movies['overview'].apply(lower)

# %%
movies.head(5)
# Out:
#                                          genres      id  \
# 0  [action, adventure, fantasy, sciencefiction]   19995
# 1                  [adventure, fantasy, action]     285
# 2                    [action, adventure, crime]  206647
# 3              [action, crime, drama, thriller]   49026
# 4           [action, adventure, sciencefiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  [in, the, 22nd, century,, a, paraplegic, marin...
# 1  [captain, barbossa,, long, believed, to, be, d...
# 2  [a, cryptic, message, from, bond’s, past, send...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, war-weary,, former, mili...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             cast                crew
# 0  [samworthington, zoesaldana, sigourneyweaver]      [jamescameron]
# 1     [johnnydepp, orlandobloom, keiraknightley]     [goreverbinski]
# 2      [danielcraig, christophwaltz, léaseydoux]         [sammendes]
# 3      [christianbale, michaelcaine, garyoldman]  [christophernolan]
# 4    [taylorkitsch, lynncollins, samanthamorton]     [andrewstanton]

# %%
(movies['cast']+movies['crew'])[0]
# Out:
# ['samworthington', 'zoesaldana', 'sigourneyweaver', 'jamescameron']

# %%
movies['tags']= movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']

# %%
movies.sample(5)
# Out:
#                              genres      id  \
# 1209                 [music, drama]  209451
# 2665                        [drama]  288980
# 3184                [comedy, drama]    9685
# 2337                [comedy, drama]  160588
# 425   [adventure, action, thriller]     954
#
#                                                keywords  \
# 1209                         [biography, based on play]
# 2665                             [ship, freedom, slave]
# 3184  [father son relationship, patenonkel, independ...
# 2337  [san francisco, sister sister relationship, ne...
# 425   [paris, london england, spy, cia, terrorist, s...
#
#                                                overview                title  \
# 1209  [from, director, clint, eastwood, comes, the, ...          Jersey Boys
# 2665  [two, men, separated, by, 100, years, are, uni...              Freedom
# 3184  [a, young, man's, peculiar, upbringing, render...       Igby Goes Down
# 2337  [jasmine, french, used, to, be, on, the, top, ...         Blue Jasmine
# 425   [when, ethan, hunt,, the, leader, of, a, crack...  Mission: Impossible
#
#                                                   cast             crew  \
# 1209  [christopherwalken, vincentpiazza, freyatingley]  [clinteastwood]
# 2665       [cubagoodingjr., williamsadler, sharonleal]   [petercousens]
# 3184         [kieranculkin, clairedanes, jeffgoldblum]     [burrsteers]
# 2337        [cateblanchett, alecbaldwin, sallyhawkins]     [woodyallen]
# 425            [tomcruise, jonvoight, emmanuellebéart]   [briandepalma]
#
#                                                    tags
# 1209  [music, drama, biography, based on play, from,...
# 2665  [drama, ship, freedom, slave, two, men, separa...
# 3184  [comedy, drama, father son relationship, paten...
# 2337  [comedy, drama, san francisco, sister sister r...
# 425   [adventure, action, thriller, paris, london en...

# %%
movies['tags'].apply(lambda x: ' '.join(x))[0]
# Out:
# 'action adventure fantasy sciencefiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. samworthington zoesaldana sigourneyweaver jamescameron'

# %%
movies['tags']=movies['tags'].apply(lambda x: ' '.join(x))

# %%
movies.sample()['tags']
# Out:
# 4050    comedy drama family small town texas four guys...
# Name: tags, dtype: object

# %%
df=movies[['id', 'title' , 'tags']]

# %%
df.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based on novel secr...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure sciencefiction based on novel...
# 5  fantasy action adventure dual identity amnesia...
# 6  animation family hostage magic horse fairy tal...
# 7  action adventure sciencefiction marvel comic s...
# 8  adventure fantasy family witch magic broom sch...
# 9  action adventure fantasy dc comics vigilante s...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4806 non-null   int64
#  1   title   4806 non-null   object
#  2   tags    4806 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 279.2+ KB

# %%
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download needed NLTK data (only once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')  # For better lemmatization
# Out:
# [nltk_data] Downloading package punkt to /home/asif-khan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/asif-
# [nltk_data]     khan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/asif-
# [nltk_data]     khan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/asif-
# [nltk_data]     khan/nltk_data...
# True

# %%
def preprocess_text(text):
    # 1. Lowercase
    text = text.lower()
    
    # 2. Tokenize
    words = word_tokenize(text)
    
    # 3. Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
    
    # 4. Stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    # 5. Return as string
    return ' '.join(stemmed_words)

# %%
preprocess_text('What is going on in the world scenario batman')
# Out:
# 'go world scenario batman'

# %%
df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based on novel secr...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure sciencefiction based on novel...

# %%
df['tags']=df['tags'].apply(preprocess_text)
# Out:
# /tmp/ipykernel_79795/91082995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(preprocess_text)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4806 non-null   int64
#  1   title   4806 non-null   object
#  2   tags    4806 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 279.2+ KB

# %%
df.to_pickle('prepared.pkl')

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.sample(1)
# Out:
#        budget                                             genres homepage  \
# 3169  9000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...      NaN
#
#           id                                           keywords  \
# 3169  238636  [{"id": 992, "name": "bus"}, {"id": 1376, "nam...
#
#      original_language      original_title  \
# 3169                en  The Purge: Anarchy
#
#                                                overview  popularity  \
# 3169  Three groups of people are trying to survive P...   82.975841
#
#                                    production_companies  \
# 3169  [{"name": "Universal Pictures", "id": 33}, {"n...
#
#                                    production_countries release_date  \
# 3169  [{"iso_3166_1": "FR", "name": "France"}, {"iso...   2014-07-17
#
#         revenue  runtime                          spoken_languages    status  \
# 3169  108782847    104.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
# ...

# %%
credits.sample(1)
# Out:
#       movie_id      title                                               cast  \
# 3910    223485  Slow West  [{"cast_id": 1, "character": "Silas", "credit_...
#
#                                                    crew
# 3910  [{"credit_id": "55a3d405925141297700569d", "de...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies['keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# genres id keywords overview title

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
# cast crew

# %%
movies=movies.merge(credits , on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies.sample(3)
# Out:
#          budget                                             genres  \
# 3334    7000000  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 159   139000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 3521    6000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                             homepage      id  \
# 3334                        http://theneondemon.com/  301365
# 159   http://www.sonypictures.com/movies/spider-man/     557
# 3521                                             NaN    8982
#
#                                                keywords original_language  \
# 3334                   [{"id": 14818, "name": "model"}]                en
# 159   [{"id": 1014, "name": "loss of lover"}, {"id":...                en
# 3521  [{"id": 188, "name": "buddhism"}, {"id": 2857,...                th
#
#       original_title                                           overview  \
# 3334  The Neon Demon  When aspiring model Jesse moves to Los Angeles...
# ...

# %%
# genres id keywords overview title 
# cast crew
movies = movies[['genres' , 'id' ,'keywords' , 'overview' , 'title' , 'cast' , 'crew']]

# %%
movies.shape
# Out:
# (4809, 7)

# %%
movies.sample(4)
# Out:
#                                                  genres      id  \
# 442   [{"id": 28, "name": "Action"}, {"id": 80, "nam...     754
# 4275                    [{"id": 37, "name": "Western"}]  218500
# 838   [{"id": 878, "name": "Science Fiction"}, {"id"...    8077
# 3731  [{"id": 80, "name": "Crime"}, {"id": 18, "name...   11826
#
#                                                keywords  \
# 442   [{"id": 1568, "name": "undercover"}, {"id": 16...
# 4275                                                 []
# 838   [{"id": 378, "name": "prison"}, {"id": 803, "n...
# 3731  [{"id": 514, "name": "spain"}, {"id": 572, "na...
#
#                                                overview  \
# 442   An antiterrorism agent goes under the knife to...
# 4275  The entire cause of the problem evolves from t...
# 838   After escaping with Newt and Hicks from the al...
# 3731  Gary is a former gangster who has made a modes...
#
#                               title  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4809 non-null   object
#  1   id        4809 non-null   int64
#  2   keywords  4809 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
movies['genres'].apply(ast.literal_eval)[0][0]
# Out:
# {'id': 28, 'name': 'Action'}

# %%
list=[]
for i in movies['genres'].apply(ast.literal_eval)[0]:
    list.append(i['name'])
print(list)
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies['genres'].apply(ast.literal_eval)
# Out:
# 0       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1       [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3       [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#                               ...
# 4804    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4805    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 4806    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4807                                                   []
# 4808                  [{'id': 99, 'name': 'Documentary'}]
# Name: genres, Length: 4809, dtype: object

# %%
def process(object):
    list=[]
    for i in object:
        list.append(i['name'])
    return list

# %%
movies['genres']=movies['genres'].apply(ast.literal_eval).apply(process)

# %%
movies.sample(3)
# Out:
#                                           genres      id  \
# 1903                             [Drama, Family]   15487
# 2847  [Horror, Drama, Thriller, Science Fiction]   16241
# 2530                                    [Comedy]  208134
#
#                                                keywords  \
# 1903                    [{"id": 6075, "name": "sport"}]
# 2847  [{"id": 7904, "name": "paraguay"}, {"id": 1024...
# 2530   [{"id": 179431, "name": "duringcreditsstinger"}]
#
#                                                overview  \
# 1903  A biopic of 20-year-old Francis Ouimet who def...
# 2847  Nazi hunter Ezra Lieberman discovers a siniste...
# 2530  86-year-old Irving Zisman is on a journey acro...
#
#                               title  \
# 1903  The Greatest Game Ever Played
# 2847           The Boys from Brazil
# 2530                    Bad Grandpa
#
#                                                    cast  \
# 1903  [{"cast_id": 1, "character": "Francis Ouimet",...
# ...

# %%
movies['keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies['keywords']=movies['keywords'].apply(ast.literal_eval).apply(process)

# %%
movies.sample(3)
# Out:
#                                  genres      id  \
# 1783  [Crime, Drama, Mystery, Thriller]  169917
# 148           [Action, Fantasy, Comedy]   43074
# 3380                    [Drama, Family]  104896
#
#                                                keywords  \
# 1783  [based on novel, murder, mafia, private invest...
# 148   [female friendship, ghost hunting, reboot, ghost]
# 3380                                                 []
#
#                                                overview  \
# 1783  Private investigator Matthew Scudder is hired ...
# 148   Following a ghost invasion of Manhattan, paran...
# 3380  Poor but happy, young Nello and his grandfathe...
#
#                             title  \
# 1783  A Walk Among the Tombstones
# 148                  Ghostbusters
# 3380            A Dog Of Flanders
#
#                                                    cast  \
# 1783  [{"cast_id": 7, "character": "Matthew Scudder"...
# ...

# %%
movies['cast'][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def process2(object):
    list=[]
    counter=0
    for i in object:
        counter=counter+1
        if counter>3:
            break
        list.append(i['name'])
        
    return list

# %%
movies['cast']=movies['cast'].apply(ast.literal_eval).apply(process2)

# %%
movies.sample(3)
# Out:
#                                         genres     id  \
# 3878  [Action, Drama, Horror, Crime, Thriller]  11564
# 1135      [Adventure, Comedy, Family, Fantasy]   9607
# 2438                                   [Drama]  24747
#
#                                                keywords  \
# 3878  [usa, female nudity, detective, music teacher,...
# 1135  [saving the world, brother brother relationshi...
# 2438                                            [sport]
#
#                                                overview  \
# 3878  Andy is a new teacher at a inner city high sch...
# 1135  Mario and Luigi, plumbers from Brooklyn, find ...
# 2438  The story of golf icon and legend, Bobby Jones...
#
#                               title  \
# 3878                  Class of 1984
# 1135              Super Mario Bros.
# 2438  Bobby Jones: Stroke of Genius
#
#                                                 cast  \
# 3878  [Perry King, Merrie Lynn Ross, Tim Van Patten]
# ...

# %%
movies['crew'][2]
# Out:
# '[{"credit_id": "54805967c3a36829b5002c41", "department": "Sound", "gender": 2, "id": 153, "job": "Original Music Composer", "name": "Thomas Newman"}, {"credit_id": "52fe4d22c3a368484e1d8d77", "department": "Directing", "gender": 2, "id": 39, "job": "Director", "name": "Sam Mendes"}, {"credit_id": "5677cd99925141691a005333", "department": "Art", "gender": 1, "id": 8384, "job": "Set Decoration", "name": "Anna Pinnock"}, {"credit_id": "52fe4d22c3a368484e1d8d8d", "department": "Writing", "gender": 2, "id": 932, "job": "Screenplay", "name": "John Logan"}, {"credit_id": "562fc9bb92514129fe0006b4", "department": "Writing", "gender": 2, "id": 932, "job": "Story", "name": "John Logan"}, {"credit_id": "5654d41c92514145c3000373", "department": "Art", "gender": 2, "id": 4248, "job": "Production Design", "name": "Dennis Gassner"}, {"credit_id": "52fe4d22c3a368484e1d8d71", "department": "Writing", "gender": 2, "id": 9856, "job": "Characters", "name": "Ian Fleming"}, {"credit_id": "54805989c3a3682
# ...

# %%
def process3(object):
    list=[]
    for i in object:
        if i['job']=='Director':
            list.append(i['name'])
            break
    return list

# %%
movies['crew']=movies['crew'].apply(ast.literal_eval).apply(process3)

# %%
movies.sample(3)
# Out:
#                             genres     id  \
# 1970   [Horror, Mystery, Thriller]   3600
# 1440  [Fantasy, Action, Adventure]    849
# 2067             [Romance, Comedy]  81836
#
#                                                keywords  \
# 1970  [competition, island, radio, bahamas, college,...
# 1440  [kingdom, lightsaber, cult favorite, dead body...
# 2067                       [rome, expatriate, episodic]
#
#                                                overview  \
# 1970  Unfinished business with coed Julie James brin...
# 1440  A prince and a fellowship of companions set ou...
# 2067  Four tales unfold in the Eternal City: While v...
#
#                                       title  \
# 1970  I Still Know What You Did Last Summer
# 1440                                  Krull
# 2067                      To Rome with Love
#
#                                                    cast            crew
# 1970  [Jennifer Love Hewitt, Freddie Prinze Jr., Mek...  [Danny Cannon]
# ...

# %%
def clean_cast(object):
    cleaned = [name.replace(" ", "") for name in object]
    return cleaned

# %%
movies['cast']=movies['cast'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#                                           genres      id  \
# 2846                             [Comedy, Drama]   11354
# 1497  [Drama, Fantasy, Romance, Science Fiction]    9294
# 1794                   [Thriller, Crime, Action]  134374
#
#                                                keywords  \
# 2846  [sex, lie, college, funeral, friendship, grief...
# 1497  [brain tumor, telekinesis, genius, terminal il...
# 1794  [miami, scam, crime, weight lifting, weightlif...
#
#                                                overview                title  \
# 2846  After her husband runs off with his secretary,...  The Upside of Anger
# 1497  An ordinary man sees a bright light descend fr...           Phenomenon
# 1794  Daniel Lugo, manager of the Sun Gym in 1990s M...          Pain & Gain
#
#                                               cast              crew
# 2846   [JoanAllen, KevinCostner, ErikaChristensen]     [Mike Binder]
# ...

# %%
movies['crew']=movies['crew'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#                          genres      id  \
# 3324             [Drama, Music]   24356
# 2556          [Comedy, Romance]    6961
# 3117  [Comedy, Family, Romance]  268171
#
#                                                keywords  \
# 3324   [journalist, musical, concert, independent film]
# 2556  [based on novel, callboy, wedding, escort, fak...
# 3117                                          [widower]
#
#                                                overview                 title  \
# 3324  Amidst unrest, organizers put on a benefit con...  Masked and Anonymous
# 2556  With the wedding of her younger sister fast ap...      The Wedding Date
# 3117  Aged, embittered widower, Fred learns to enjoy...           Elsa & Fred
#
#                                                   cast              crew
# 3324             [BobDylan, JeffBridges, PenélopeCruz]    [LarryCharles]
# 2556          [DebraMessing, DermotMulroney, AmyAdams]     [ClareKilner]
# ...

# %%
movies['genres']=movies['genres'].apply(clean_cast)

# %%
movies.sample(3)
# Out:
#                 genres      id  \
# 1407      [Drama, War]     423
# 3880  [Romance, Drama]  108346
# 3142          [Comedy]   16614
#
#                                                keywords  \
# 1407  [individual, resistance, radio station, war cr...
# 3880                                 [lust, love crime]
# 3142  [comedy, cheating on partner, amusement park, ...
#
#                                                overview  \
# 1407  The Pianist is a film adapted from the biograp...
# 3880  Set in rural England in the 1950s Eva (Samanth...
# 3142  In the summer of 1987, a college graduate take...
#
#                         title  \
# 1407              The Pianist
# 3880  Dreaming of Joseph Lees
# 3142            Adventureland
#
#                                                   cast             crew
# 1407     [AdrienBrody, ThomasKretschmann, FrankFinlay]  [RomanPolanski]
# 3880  [RupertGraves, SamanthaMorton, NicholasWoodeson]     [EricStyles]
# ...

# %%
def lower(object):
    return [name.lower() for name in object]

# %%
movies['genres']=movies['genres'].apply(lower)
movies['cast']=movies['cast'].apply(lower)
movies['keywords']=movies['keywords'].apply(lower)
movies['crew']=movies['crew'].apply(lower)
movies.sample(5)
# Out:
#                               genres     id  \
# 1224                 [comedy, drama]  10385
# 734   [adventure, animation, family]  10199
# 3220                         [drama]  16727
# 4608                         [drama]    389
# 1183                 [comedy, crime]  11565
#
#                                                keywords  \
# 1224  [sister sister relationship, cheating, amnesia...
# 734   [loyalty, totalitarian regime, mouse, forgiven...
# 3220    [indian lead, independent film, woman director]
# 4608  [judge, jurors, sultriness, death penalty, fat...
# 1183  [undercover, nanny, computer virus, stress, un...
#
#                                                overview  \
# 1224  A trio of sisters bond over their ambivalence ...
# 734   Once upon a time... in the far away kingdom of...
# 3220  American-born Gogol, the son of Indian immigra...
# 4608  The defense and the prosecution have rested an...
# 1183  FBI agent Malcolm Turner goes back undercover ...
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4809 non-null   object
#  1   id        4809 non-null   int64
#  2   keywords  4809 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
def process5(object):
    return object.split()

# %%
movies.dropna(inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   overview  4806 non-null   object
#  4   title     4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.4+ KB

# %%
movies['overview']=movies['overview'].apply(process5)

# %%
print(process5("Hey how are you 1950"))
# Out:
# ['Hey', 'how', 'are', 'you', '1950']

# %%
movies['overview']=movies['overview'].apply(lower)

# %%
movies.head(5)
# Out:
#                                          genres      id  \
# 0  [action, adventure, fantasy, sciencefiction]   19995
# 1                  [adventure, fantasy, action]     285
# 2                    [action, adventure, crime]  206647
# 3              [action, crime, drama, thriller]   49026
# 4           [action, adventure, sciencefiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  [in, the, 22nd, century,, a, paraplegic, marin...
# 1  [captain, barbossa,, long, believed, to, be, d...
# 2  [a, cryptic, message, from, bond’s, past, send...
# 3  [following, the, death, of, district, attorney...
# ...

# %%
(movies['cast']+movies['crew'])[0]
# Out:
# ['samworthington', 'zoesaldana', 'sigourneyweaver', 'jamescameron']

# %%
movies['tags']= movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']

# %%
movies.sample(5)
# Out:
#                                     genres      id  \
# 390   [animation, comedy, family, fantasy]   76492
# 2865   [adventure, drama, action, romance]    9550
# 209                     [action, thriller]   49040
# 3368                      [romance, drama]  241771
# 3623                              [comedy]    9900
#
#                                                keywords  \
# 390   [witch, magic, mummy, vampire, dracula, skelet...
# 2865  [martial arts, swordplay, government, rebellio...
# 209   [assassin, wolf, maryland, suicide by gunshot,...
# 3368        [talent, success, musician, woman director]
# 3623  [video game, grandmother grandson relationship...
#
#                                                overview  \
# 390   [dracula,, who, operates, a, high-end, resort,...
# 2865  [in, 9th, century, china,, a, corrupt, governm...
# 209   [new, cia, operative,, aaron, cross, experienc...
# 3368  [noni, jean, is, a, hot, new, rising, star., b...
# ...

# %%
movies['tags'].apply(lambda x: ' '.join(x))[0]
# Out:
# 'action adventure fantasy sciencefiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. samworthington zoesaldana sigourneyweaver jamescameron'

# %%
movies['tags']=movies['tags'].apply(lambda x: ' '.join(x))

# %%
movies.sample()['tags']
# Out:
# 2816    comedy drama hairdresser shop neighbor debt me...
# Name: tags, dtype: object

# %%
df=movies[['id', 'title' , 'tags']]

# %%
df.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based on novel secr...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure sciencefiction based on novel...
# 5  fantasy action adventure dual identity amnesia...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4806 non-null   int64
#  1   title   4806 non-null   object
#  2   tags    4806 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 279.2+ KB

# %%
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# Download required NLTK datasets quietly
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True) # Catch for newer NLTK versions
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

def preprocess_text(text):
    # 1. Lowercase
    text = str(text).lower() # Added str() just in case you pass a null/float value
    
    # 2. Tokenize
    words = word_tokenize(text)
    
    # 3. Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
    
    # 4. Stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    # 5. Return as string
    return " ".join(stemmed_words)

# %%
preprocess_text('What is going on in the world scenario batman')
# Out:
# 'go world scenario batman'

# %%
df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based on novel secr...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure sciencefiction based on novel...

# %%
df['tags']=df['tags'].apply(preprocess_text)
# Out:
# /tmp/ipykernel_90698/91082995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(preprocess_text)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4806 non-null   int64
#  1   title   4806 non-null   object
#  2   tags    4806 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 279.2+ KB

# %%
df.to_pickle('prepared.pkl')
